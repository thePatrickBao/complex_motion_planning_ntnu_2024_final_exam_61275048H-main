# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import math
from IPython.display import display, HTML
import cv2

# %%
student_id = input("Enter your student id")
student_name = input("Enter your name")
print("STUDENT ID", student_id)
print("STUDENT NAME", student_name)
# Out:
# STUDENT ID 61275048H
# STUDENT NAME Patrick Bao

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Quadtree Decomposition</h1>
# <div class="question_body">
#
# <p><a href="https://en.wikipedia.org/wiki/Quadtree">Quadtree Decomposition</a> is a powerful
# and versatile cell decomposition algorithm for motion planning problems.</p>
#
# <p>Given below is a simple navigation domain.</p>
#
# <div>
#
#
# <a download="Quadtree Environment" href="data:image/png;base64,...">
#
#
# <img src="data:image/png;base64,..." alt="Quadtree Environment"/>
#
# </a>
#
# </div>
#
# <p>The robot can move in one of four directions: up, down, left, and right.</p>
#
# <p>The domain is represented as an occupancy grid.</p>
#
# </div><!-- end of question_body -->

# %%
00000000
00010000
00000000
00000000
00000000
00100000
00011100
00011100
# Out:
#   Cell In[4], line 2
#     00010000
#            ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %% [markdown]
# <div class="question_marks">
# <span class="mark_num" style="text-align:right">15</span> marks
# </div><!-- end of question_marks -->

# %% [markdown]
# <p>Show the output of the quadtree decomposition algorithm for this domain
# and indicate the number of cells of size 1, 4, and 16 in the quadtree decomposition
# of this domain.</p>
#
# <div>
# <p>Number of cells of size 1:   64</p>
# <p>Number of cells of size 4:   16</p>
# <p>Number of cells of size 16:  4</p>
# </div>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# size 1 => 4^3 = 64
# size 4 => 4^2 = 16
# size 16 => 4^1 = 4

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Estimated Runtime Breadth First Search</h1>
# <div class="question_body">
#
# <p>You estimate the performance of standard breadth first search (BFS) algorithm.</p>
#
# <p>Each node expansion of the BFS algorithm takes 4000 milliseconds.</p>
# <p>The average length of a solution path using the BFS algorithm is 22 steps.</p>
#
# </div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks">
# <span class="mark_num" style="text-align:right">5</span> marks
# </div><!-- end of question_marks -->

# %% [markdown]
# Estimate the worst case runtime of the BFS algorithm assuming that the the time per node
# is 4000 milliseconds and the length of the solution is 22 steps:
#
# Expected runtime BFS: 120000 milliseconds

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# My idea is that each node can extend out 2 subnodes, and the total number of nodes is 2^1+2^2+2^3+2^4 = 30 ,the wrost case is run all nodes, so 30 x 4000 milliseconds = 120000 milliseconds

# %% [markdown]
# <h1>Estimated Runtime A*</h1>
# <div class="question_body">
#
# <p>You estimate the performance of standard A* search algorithm.</p>
#
# <p>Each node expansion of the A* algorithm takes 4000 milliseconds.</p>
# <p>The average length of a solution path using the A* algorithm is 22 steps.</p>
# <p>You use an admissible heuristic, which eliminates on average 70% of the possible
# choices at each node.</p>
#
# </div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks">
# <span class="mark_num" style="text-align:right">5</span> marks
# </div><!-- end of question_marks -->

# %% [markdown]
# <p>Estimate the worst case runtime of the A* algorithm assuming that the the time per node
# is 4000 milliseconds, the length of the solution is 22 steps, and your heuristic
# eliminates on average 70% of the possible choices at each node:</p>
#
# <p>Expected runtime A* search: 28 sec</p>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# 22 x 0.3 = 6.6 nodes  7 nodes x 4 second = 28 sec

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Estimated Runtime Quadtree Decomposition</h1>
# <div class="question_body">
#
# <p>You estimate the performance of standard Quadtree Decomposition algorithm.</p>
#
# <p>Using quadtree decomposition, you can reduce the depth of your search by 30%
# but the cost per node increases by 30%, so that each node expansion takes now
# 6400 milliseconds.</p>
#
# <p>You use the A* search algorithm to search the result of the quadtree decompositon.
# Your admissible heuristic eliminates on average 70% of the possible choices at each
# node:</p>
#
# </div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks">
# <span class="mark_num" style="text-align:right">5</span> marks
# </div><!-- end of question_marks -->

# %% [markdown]
# <p>Estimate the worst case runtime of the Quadtree decomposition algorithm assuming
# that the the time per node
# is 6400 milliseconds, quadtree decompposition reduces the depth of the search
# by 30%, and your heuristic
# eliminates on average 70% of the possible choices at each node:</p>
#
# <p>Expected runtime of quadtree decompositon search: 6400×1.3^0.7D milliseconds D is original depth</p>

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# After quadtree decomposition, the depth of the search tree is reduced by 30%. So, if the original depth is D, the effective depth after decomposition is 0.7D.   nodes expanded in wrost case is 1.3^0.7D than 6400 x 1.3 ^ 0.7 milliseconds

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->

# %% [markdown]
# <!-- <div class="question_frame"> --><!-- start of question_frame -->

# %% [markdown]
# <h1>Flexible Binary Space Partitioning</h1>
# <div class="question_body">
#
# <p>You estimate the performance of standard Quadtree Decomposition algorithm.</p>
#
# <p>Using quadtree decomposition, you can reduce the depth of your search by 30%
# but the cost per node increases by 30%, so that each node expansion takes now
# 6400 milliseconds.</p>
#
# <p>You use the A* search algorithm to search the result of the quadtree decompositon.
# Your admissible heuristic eliminates on average 70% of the possible choices at each
# node:</p>
#
# </div><!-- end of question_body -->

# %% [markdown]
# <h1>Flexible Binary Space Partitioning</h1>
# <div class="question_body">
#
# <p>I developed the <a href="http://aalab.cs.umanitoba.ca/%7Ejacky/Publications/pdf/baltes03:_flexib_binar_space_partit_robot_rescue.pdf">
# flexible binary space partitioning (FBSP)</a> algorithm
# together with my colleague John Anderson.</p>
#
# <p>A copy of the research paper is available in the <code>Resources</code> folder.</p>
#
# <p>Implement a simplified version of the FBSP algorithm for this domain and compare the
# number of leaf cells generated by the quadtree decomposition and FBSP algorithm.</p>
#
# <p>Instead of using the projection as described in Figure 4 of the paper, you can
# use any coordinate that corresponds with an edge when selecting a split point.</p>
#
# </div><!-- end of question_body -->

# %% [markdown]
# <div class="question_marks">
# <span class="mark_num" style="text-align:right">25</span> marks
# </div><!-- end of question_marks -->

# %%
def fbsp_decomposition(env):
    
    def entropy(subspace):
        total = subspace.size
        if total == 0:
            return 0
        p_free = np.sum(subspace == 0) / total
        p_blocked = np.sum(subspace == 1) / total
        if p_free == 0 or p_blocked == 0:
            return 0
        return -p_free * np.log2(p_free) - p_blocked * np.log2(p_blocked)

    def best_split(x, y, width, height):
        best_gain = -1
        best_point = None
        initial_entropy = entropy(space[y:y + height, x:x + width])
        for i in range(x + 1, x + width):
            left = space[y:y + height, x:i]
            right = space[y:y + height, i:x + width]
            gain = initial_entropy - (entropy(left) * (i - x) + entropy(right) * (x + width - i)) / width
            if gain > best_gain:
                best_gain = gain
                best_point = ('vertical', i)
        for j in range(y + 1, y + height):
            top = space[y:j, x:x + width]
            bottom = space[j:y + height, x:x + width]
            gain = initial_entropy - (entropy(top) * (j - y) + entropy(bottom) * (y + height - j)) / height
            if gain > best_gain:
                best_gain = gain
                best_point = ('horizontal', j)
        return best_point

    def partition(x, y, width, height):
        if width == 1 and height == 1:
            return 1 if space[y, x] == 1 else 0
        split = best_split(x, y, width, height)
        if split is None:
            return 1
        direction, point = split
        if direction == 'vertical':
            left = partition(x, y, point - x, height)
            right = partition(point, y, width - (point - x), height)
            return left + right + 1
        else:
            top = partition(x, y, width, point - y)
            bottom = partition(x, point, width, height - (point - y))
            return top + bottom + 1

    return partition(0, 0, space.shape[1], space.shape[0])

fbsp_leaves = fbsp(space)
print("FBSP leaf cells:", fbsp_leaves)

# %% [markdown]
# <p>Show your work and explain your answer in this cell. You can add additional markdown and code cells, if you want to after this cell.</p>

# %% [markdown]
# <!-- </div> --><!-- end of question_frame -->
